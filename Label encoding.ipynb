# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
labeled_class=le.fit_transform(df['class'])

# %%
le.classes_
# Out:
# array(['First', 'Second', 'Third'], dtype=object)

# %%
le.inverse_transform(labeled_class)
# Out:
# array(['Third', 'First', 'Third', 'First', 'Third', 'Third', 'First',
#        'Third', 'Third', 'Second', 'Third', 'First', 'Third', 'Third',
#        'Third', 'Second', 'Third', 'Second', 'Third', 'Third', 'Second',
#        'Second', 'Third', 'First', 'Third', 'Third', 'Third', 'First',
#        'Third', 'Third', 'First', 'First', 'Third', 'Second', 'First',
#        'First', 'Third', 'Third', 'Third', 'Third', 'Third', 'Second',
#        'Third', 'Second', 'Third', 'Third', 'Third', 'Third', 'Third',
#        'Third', 'Third', 'Third', 'First', 'Second', 'First', 'First',
#        'Second', 'Third', 'Second', 'Third', 'Third', 'First', 'First',
#        'Third', 'First', 'Third', 'Second', 'Third', 'Third', 'Third',
#        'Second', 'Third', 'Second', 'Third', 'Third', 'Third', 'Third',
#        'Third', 'Second', 'Third', 'Third', 'Third', 'Third', 'First',
#        'Second', 'Third', 'Third', 'Third', 'First', 'Third', 'Third',
# ...

# %%
df.drop(['class'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
df['class']=labeled_class

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
# 5         0       3    male   NaN      0      0   8.4583        Q    man
# 6         0       1    male  54.0      0      0  51.8625        S    man
# 7         0       3    male   2.0      3      1  21.0750        S  child
# 8         1       3  female  27.0      0      2  11.1333        S  woman
# 9         1       2  female  14.0      1      0  30.0708        C  child
#
#    adult_male deck  embark_town alive  alone  class
# 0        True  NaN  Southampton    no  False      2
# 1       False    C    Cherbourg   yes  False      0
# ...

# %% [markdown]
# # label encoding with multiple columns

# %%
tip=sns.load_dataset('tips')
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_encoded = tip.iloc[:,[2,3,4]].apply(le.fit_transform)

# %%
df_encoded # after that we can concatenate this encoded frame with original data frame
# Out:
#      sex  smoker  day
# 0      0       0    2
# 1      1       0    2
# 2      1       0    2
# 3      1       0    2
# 4      0       0    2
# ..   ...     ...  ...
# 239    1       0    1
# 240    0       1    1
# 241    1       1    1
# 242    1       0    1
# 243    0       0    3
#
# [244 rows x 3 columns]
